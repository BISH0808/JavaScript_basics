# %% [markdown]
# <a href="https://colab.research.google.com/github/BISH0808/JavaScript_basics/blob/main/Notes_from_UlbiTV_video/Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Введение

# %% [markdown]
# В ходе данного курса  [UlbiTV](https://www.youtube.com/@UlbiTV) рассматривает

# %% [markdown]
# ![image.png](data:image/png;base64,...)
