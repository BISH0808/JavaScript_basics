# %% [markdown]
# <a href="https://colab.research.google.com/github/BISH0808/JavaScript_basics/blob/main/Notes_from_UlbiTV_video/React_Dev_Tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # React Devtools. Инструменты разработчика React

# %% [markdown]
# * Ниже будет показано, как работать с инструментами разработчика и отлаживать React.

# %% [markdown]
# * Для начала надо загуглить *react devtools*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Устанавливаем React Dev Tools в **расширения**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Теперь видим в режиме разработчика 2 новые вкладки **Components** и **Profiler**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Здесь можно увидеть все дерево компонентов в нашем приложении, посмотреть, какое там есть состояние, чему оно равно.
# * Прям там можно изменить состояние и посмотреть, как интерфейс на изменение этого состояния отреагирует.
# * Также там можно сразу посомтреть, какие пропсы принимает компонент.
