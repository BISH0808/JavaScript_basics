# %% [markdown]
# <a href="https://colab.research.google.com/github/BISH0808/JavaScript_basics/blob/main/Notes_from_UlbiTV_video/JSX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Что такое  JSX?

# %% [markdown]
# # Как мы пишем html-разметку внутри js-файла?

# %% [markdown]
# * Такой синтакисис называется jsx. Он является расширением JavaScript и упрощает написание кода.

# %% [markdown]
# * Снизу сравнение код с JSX (слева) и без JSX (справа)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * создание элемента "Кнопка" без JSX

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * создание элемента "Кнопка" c JSX

# %% [markdown]
# ![image.png](data:image/png;base64,...)
